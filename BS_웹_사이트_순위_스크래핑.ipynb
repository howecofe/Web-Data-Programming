# %% [markdown]
# # BeautifulSoup 웹 사이트 순위 스크래핑
#
# * Alexa: https://www.alexa.com/topsites

# %% [markdown]
# ##글로벌 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':"tr site-listing"})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text() #리스트 중 첫번째 요소
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking] #rank를 인덱스로 rank_df 값 채워줌

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,567,347
# 2     2          Youtube.com  ...                   15.20%              1,192,423
# 3     3            Baidu.com  ...                    5.10%                116,207
# 4     4               Qq.com  ...                    3.00%                286,730
# 5     5             Sohu.com  ...                    1.60%                 30,436
# 6     6         Facebook.com  ...                    8.30%              2,739,156
# 7     7           Taobao.com  ...                    3.20%                 28,584
# 8     8               360.cn  ...                    0.40%                 16,974
# 9     9               Jd.com  ...                    1.40%                  9,680
# 10   10            Yahoo.com  ...                    7.80%                363,317
# 11   11           Amazon.com  ...                   19.80%                408,794
# 12   12        Wikipedia.org  ...                   73.20%                932,190
# 13   13          Sina.com.cn  ...                    2.60%                 54,266
# 14   14            Weibo.com  ...                    2.00%                 78,715
# 15   15           Reddit.com  ...                   28.50%                201,792
# 16   16             Live.com  ...                   10.60%                 33,383
# 17   17              Zoom.us  ...                   15.60%                  2,799
# 18   18          Netflix.com  ...                    9.40%                 11,487
# 19   19        Xinhuanet.com  ...                    2.70%                 39,005
# 20   20          Okezone.com  ...                    6.40%                 12,755
# 21   21        Microsoft.com  ...                   28.80%                286,315
# 22   22        Instagram.com  ...                   13.60%                782,268
# 23   23               Vk.com  ...                    9.00%                167,963
# 24   24           Alipay.com  ...                    1.40%                  3,925
# 25   25        Myshopify.com  ...                    3.30%                    122
# 26   26           Office.com  ...                    8.30%                  6,257
# 27   27             Csdn.net  ...                    7.00%                  7,334
# 28   28          Yahoo.co.jp  ...                   12.70%                 62,592
# 29   29            Twitch.tv  ...                    6.50%                 11,065
# 30   30             Panda.tv  ...                    0.80%                    390
# 31   31        Bongacams.com  ...                    8.50%                134,623
# 32   32            Zhanqi.tv  ...                    0.80%                    399
# 33   33        Google.com.hk  ...                    3.10%                  9,072
# 34   34             Bing.com  ...                    5.90%                 47,211
# 35   35       Aliexpress.com  ...                   13.70%                 23,093
# 36   36            Naver.com  ...                   10.00%                 47,724
# 37   37             Ebay.com  ...                   15.90%                 83,088
# 38   38         China.com.cn  ...                    1.10%                 14,372
# 39   39            Amazon.in  ...                   25.70%                  7,740
# 40   40  Microsoftonline.com  ...                    3.00%                    775
# 41   41            Tianya.cn  ...                    1.00%                  6,664
# 42   42    Stackoverflow.com  ...                   74.50%                 29,937
# 43   43          Twitter.com  ...                   11.60%              2,001,815
# 44   44         Amazon.co.jp  ...                   16.10%                 53,459
# 45   45       Tribunnews.com  ...                   61.50%                 23,858
# 46   46         Google.co.in  ...                   10.00%                 17,766
# 47   47       Chaturbate.com  ...                    9.80%                 77,607
#
# [47 rows x 6 columns]

# %% [markdown]
# ##미국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/US"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':"tr site-listing"})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text() #리스트 중 첫번째 요소
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking] #rank를 인덱스로 rank_df 값 채워줌

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,567,347
# 2     2          Youtube.com  ...                   15.20%              1,192,423
# 3     3           Amazon.com  ...                   19.80%                408,794
# 4     4            Yahoo.com  ...                    7.80%                363,317
# 5     5         Facebook.com  ...                    8.30%              2,739,156
# 6     6           Reddit.com  ...                   28.50%                201,792
# 7     7              Zoom.us  ...                   15.60%                  2,799
# 8     8        Wikipedia.org  ...                   73.20%                932,190
# 9     9        Myshopify.com  ...                    3.30%                    122
# 10   10             Ebay.com  ...                   15.90%                 83,088
# 11   11          Netflix.com  ...                    9.40%                 11,487
# 12   12             Bing.com  ...                    5.90%                 47,211
# 13   13           Office.com  ...                    8.30%                  6,257
# 14   14             Live.com  ...                   10.60%                 33,383
# 15   15            Twitch.tv  ...                    6.50%                 11,065
# 16   16        Microsoft.com  ...                   28.80%                286,315
# 17   17        Instagram.com  ...                   13.60%                782,268
# 18   18       Chaturbate.com  ...                    9.80%                 77,607
# 19   19            Chase.com  ...                    8.60%                  1,308
# 20   20  Microsoftonline.com  ...                    3.00%                    775
# 21   21           Zillow.com  ...                   31.50%                 10,105
# 22   22              Cnn.com  ...                   21.70%                123,572
# 23   23            Apple.com  ...                   36.90%                208,210
# 24   24         Linkedin.com  ...                   13.80%                768,830
# 25   25             Etsy.com  ...                   19.90%                109,925
# 26   26          Walmart.com  ...                   28.80%                 19,231
# 27   27       Aliexpress.com  ...                   13.70%                 23,093
# 28   28          Dropbox.com  ...                    7.60%                 25,722
# 29   29             Espn.com  ...                   12.40%                 10,295
# 30   30          Nytimes.com  ...                   28.40%                178,578
# 31   31       Craigslist.org  ...                   22.40%                 15,809
# 32   32            Adobe.com  ...                   25.20%                305,686
# 33   33          Twitter.com  ...                   11.60%              2,001,815
# 34   34      Instructure.com  ...                    6.40%                  1,049
# 35   35       Wellsfargo.com  ...                   11.50%                  2,350
# 36   36             Okta.com  ...                    2.90%                    265
# 37   37       Livejasmin.com  ...                    3.60%                 12,688
# 38   38            Imgur.com  ...                    7.90%                262,814
# 39   39        Homedepot.com  ...                   44.20%                 13,037
# 40   40       Salesforce.com  ...                    5.90%                  4,985
# 41   41             Hulu.com  ...                    9.40%                 11,800
# 42   42          Pornhub.com  ...                   26.10%                  4,644
# 43   43             Usps.com  ...                   22.80%                  8,363
# 44   44             Imdb.com  ...                   47.40%                158,244
# 45   45              Msn.com  ...                    7.20%                105,666
# 46   46           Indeed.com  ...                   25.60%                  8,596
# 47   47    Stackoverflow.com  ...                   74.50%                 29,937
# 48   48               Ca.gov  ...                   31.70%                 44,576
# 49   49            Force.com  ...                    2.50%                  3,553
#
# [49 rows x 6 columns]

# %% [markdown]
# ##한국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/KR"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':"tr site-listing"})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text() #리스트 중 첫번째 요소
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking] #rank를 인덱스로 rank_df 값 채워줌

rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search Total Sites Linking In
# 1     1         Google.com  ...                    0.40%              1,567,347
# 2     2          Naver.com  ...                   10.00%                 47,724
# 3     3        Youtube.com  ...                   15.20%              1,192,423
# 4     4           Daum.net  ...                    4.90%                 17,579
# 5     5        Tistory.com  ...                   24.80%                 10,320
# 6     6          Kakao.com  ...                    8.30%                 13,192
# 7     7       Google.co.kr  ...                   10.60%                  4,954
# 8     8         Amazon.com  ...                   19.80%                408,794
# 9     9           Sohu.com  ...                    1.60%                 30,436
# 10   10             Qq.com  ...                    3.00%                286,730
# 11   11       Facebook.com  ...                    8.30%              2,739,156
# 12   12          Namu.wiki  ...                   21.70%                    115
# 13   13        Netflix.com  ...                    9.40%                 11,487
# 14   14      Wikipedia.org  ...                   73.20%                932,190
# 15   15         Taobao.com  ...                    3.20%                 28,584
# 16   16        Coupang.com  ...                   13.10%                    459
# 17   17             Jd.com  ...                    1.40%                  9,680
# 18   18             360.cn  ...                    0.40%                 16,974
# 19   19          Baidu.com  ...                    5.10%                116,207
# 20   20       Dcinside.com  ...                   18.90%                    840
# 21   21      Microsoft.com  ...                   28.80%                286,315
# 22   22          Twitch.tv  ...                    6.50%                 11,065
# 23   23          Yahoo.com  ...                    7.80%                363,317
# 24   24           Nate.com  ...                    5.00%                  2,527
# 25   25      Instagram.com  ...                   13.60%                782,268
# 26   26      Gmarket.co.kr  ...                   16.30%                  2,445
# 27   27          Apple.com  ...                   36.90%                208,210
# 28   28        Sina.com.cn  ...                    2.60%                 54,266
# 29   29          Weibo.com  ...                    2.00%                 78,715
# 30   30          Nexon.com  ...                   12.60%                    762
# 31   31  Stackoverflow.com  ...                   74.50%                 29,937
# 32   32         Office.com  ...                    8.30%                  6,257
# 33   33          Donga.com  ...                   18.10%                  4,605
# 34   34          Adobe.com  ...                   25.20%                305,686
# 35   35          Yna.co.kr  ...                   14.30%                    581
# 36   36         11st.co.kr  ...                    3.40%                  1,340
# 37   37           Bing.com  ...                    5.90%                 47,211
# 38   38         Chosun.com  ...                   23.90%                  7,773
# 39   39      Auction.co.kr  ...                   12.00%                  1,388
# 40   40      Afreecatv.com  ...                    5.90%                    537
# 41   41           Ebay.com  ...                   15.90%                 83,088
# 42   42        Inven.co.kr  ...                   33.10%                  1,358
# 43   43       Amazon.co.uk  ...                   19.00%                 63,050
# 44   44          Joins.com  ...                   23.50%                  5,735
# 45   45        Yahoo.co.jp  ...                   12.70%                 62,592
# 46   46        Dropbox.com  ...                    7.60%                 25,722
# 47   47        Ruliweb.com  ...                   16.10%                    523
# 48   48       Amazon.co.jp  ...                   16.10%                 53,459
#
# [48 rows x 6 columns]
