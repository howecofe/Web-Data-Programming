# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[idx] = [title, link, description] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 컴퓨터
#                           Title  ...                                        Description
# 0                    컴퓨터 - 나무위키  ...  컴퓨터에 대한 내용은 PC 문서를 참조하십시오. 관련 문서: 전자기기 관련 정보, ...
# 1                  슈퍼컴퓨터 - 나무위키  ...  가장 빠른 슈퍼컴퓨터 연혁 4.2. 대한민국의 슈퍼컴퓨터 도입 4.2.1. 기상청 ...
# 2                          주연테크  ...  주연테크 회사소개 및 컴퓨터,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 ...
# 3                          TG삼보  ...                  컴퓨터, 모니터, 노트북 제조판매 등 제품소개, AS 안내.
# 4                        한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# ..                          ...  ...                                                ...
# 195                  컴퓨터학부 특강안내  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 132 등록일 : 2019-11-21...
# 196           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 495 등록일 : 2019...
# 197  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 97 등록일 : 2019-11-21 ...
# ...

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000
sort = "sim" #sim: 유사도순, date: 날짜순, point: 평점순

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의: 컴퓨터
#                Title  ...                                        Description
# 0        학점은행제 컴퓨터공학  ...  ... 하던데 컴퓨터공학 있나요? 학점은행제 컴퓨터공학은 전공이 있나요 없나요? 학...
# 1            조립식컴퓨터랑  ...  조립식컴퓨터랑 그냥 컴퓨터랑 성능 면에서 차이가 있나요? 질문자님을 뵙게 되어 감사...
# 2      컴퓨터공학 학위취득!!!  ...  안녕하세요 학점은행제 컴퓨터공학 취득하려고 하는데 최종학력은 고졸입니다 고등학교때 ...
# 3         컴퓨터활용능력 인강  ...  컴퓨터활용능력 인강 추천좀 해주세요 싸면 더 좋구요 아니면은 진짜 괜찮은 컴퓨터활용...
# 4         컴퓨터학원 좋은곳?  ...  ... 컴퓨터학원 다니면서 실력을 키워보고 싶은데용. 어디 컴퓨터학원이 괜찮을까요?...
# ..               ...  ...                                                ...
# 995    컴퓨터보안전문가가 되려면  ...  ... 근데 그냥저냥 한동안 잊고 살았는데, 얼마전에 컴퓨터보안전문가 에 대해 알게...
# 996           컴퓨터 견적  ...  제가 컴퓨터를 사려고 하는데 gta5 오버워치... 쓰고 컴퓨터가 좋아야합니다 gt...
# 997   컴퓨터공학과에 대한 질문!  ...  안녕하세요 한 몇주전쯤 어떤 엔지니어분이 저희집 컴퓨터를 원격조종해주시는 것을 보고...
# 998  학점은행제 컴퓨터공학 설명좀  ...  ... 고졸이구요 컴퓨터공학을 생각중인데 수능봐서 입학할 형편은 안됩니다... 학점...
# 999        청주 컴퓨터 학원  ...  ... 제가 컴퓨터 학원을 다니려고 하거든요 알아봤을때는 이근처에 컴퓨터 학원이 없...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"  #sim: 유사도순, date: 날짜순

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "Publication Date"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/news?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        original_link = items[item_index]['originallink']
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pub_date = items[item_index]['pubDate']
        news_df.loc[idx] = [title, original_link, link, description, pub_date] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

news_df
# Out:
# 검색 질의: 컴퓨터
#                                              Title  ...                 Publication Date
# 0                       핵융합 상용화 난제 해결할 슈퍼컴퓨터 구축 완료  ...  Mon, 24 Aug 2020 23:37:00 +0900
# 1                       핵융합 상용화 난제 해결할 슈퍼컴퓨터 구축 완료  ...  Mon, 24 Aug 2020 09:17:00 +0900
# 2                     비트컴퓨터, 의원급 의료기관용 클라우드 플랫폼 출시  ...  Tue, 25 Aug 2020 10:42:00 +0900
# 3                핵융합연구소, 슈퍼컴퓨터 '카이로스' 가동 시작…1PF 성능  ...  Mon, 24 Aug 2020 15:42:00 +0900
# 4                           비트컴퓨터, 의원용 클라우드 플랫폼 출시  ...  Tue, 25 Aug 2020 10:22:00 +0900
# ..                                             ...  ...                              ...
# 995                           과기정통부, 슈퍼컴퓨터 자체개발 지원  ...  Thu, 26 Mar 2020 11:16:00 +0900
# 996                삼성전자, 중국 쑤저우공장 컴퓨터 생산 중단·대규모 감원  ...  Sat, 01 Aug 2020 13:37:00 +0900
# 997                넥슨 컴퓨터박물관, 코로나19 확산 방지 위해 휴관 연장  ...  Wed, 11 Mar 2020 16:02:00 +0900
# ...

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000
sort = "sim" #sim: 유사도순, date: 날짜순

blog_df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name", "Blogger Link", "Post Date"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        blogger_name =  items[item_index]['bloggername']
        blogger_link = items[item_index]['bloggerlink']
        post_date = items[item_index]['postdate']
        blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의: 컴퓨터
#                                    Title  ... Post Date
# 0                        용산 조립컴퓨터 만족스러워요  ...  20200824
# 1                   국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 2                      컴퓨터학원 눈 여겨 봐야할 점!  ...  20200819
# 3                  강남컴퓨터학원 전문가로 성장하는 과정!  ...  20200708
# 4         한성컴퓨터 가성비 노트북 올데이롱 TFX255S 사용기  ...  20200806
# ..                                   ...  ...       ...
# 995    가성비 좋은 잘만 N5 MF RGB 튜닝 컴퓨터 케이스 후기  ...  20200401
# 996             미국의 인기 직종, 컴퓨터 엔지니어와 간호사  ...  20191030
# 997    사진정리, 스마트폰과 컴퓨터의 디지털 사진을 찾기쉽게...   ...  20190826
# 998              컴퓨터 CPU 온도 측정하는 방법 알아보기  ...  20190920
# 999  컴퓨터 파워 교체방법: 선 연결 하는 곳. 잘만테크 파워서플라이  ...  20191111
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000
sort = "sim" #sim: 유사도순, date: 날짜순, count: 판매량순

book_df = pd.DataFrame(columns=("Title", "Link", "Image", "Author", "Price", "Discount", "Publisher", "ISBN", "Description", "Publication Date"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/book?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        image = items[item_index]['image']
        author = items[item_index]['author']
        price = items[item_index]['price']
        discount = items[item_index]['discount']
        publisher = items[item_index]['publisher']
        isbn = items[item_index]['isbn']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pubdate = items[item_index]['pubdate']
        book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn, description, pubdate] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

book_df
# Out:
# 검색 질의: 컴퓨터
#                                                  Title  ... Publication Date
# 0    시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 1                              시나공 컴퓨터활용능력 2급실기 (2020)  ...         20191008
# 2                              시나공 컴퓨터활용능력1급 실기 (2020)  ...         20191010
# 3    시나공 총정리 컴퓨터활용능력 2급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 4    시나공 컴퓨터활용능력 1급 필기 (필수암기집+동영상강의+암기프로그램+기출CBT,2020)  ...         20191028
# ..                                                 ...  ...              ...
# 995  컴퓨터 일반 쪽집게 기출문제집 + 정답 및 해설 세트 (2017,전산직 계리직 군무...  ...         20170104
# 996              이기적 in 컴퓨터그래픽스 운용기능사 필기 기본서 세트 (2016)  ...         20151030
# 997                                            언어와 컴퓨터  ...         20160520
# 998                                         수학 그리고 컴퓨터  ...         20130901
# 999                   우정사업본부 지방우정청 9급 계리직 심화문제특강 컴퓨터일반  ...         20151020
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000

movie_df = pd.DataFrame(columns=("Title", "Link", "Image", "Subtitle", "Publication Date", "Director", "Actor", "User Rating"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        image = items[item_index]['image']
        subtitle = items[item_index]['subtitle']
        pub_date = items[item_index]['pubDate']
        director = items[item_index]['director']
        actor = items[item_index]['actor']
        user_rating = items[item_index]['userRating']
        movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

movie_df
# Out:
# 검색 질의: 아이언맨
#                    Title  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re     #regular expression: 태그 제거

client_id = "gEA4FviwYGyUsGznUQk2"
client_secret = "l4yUNyFg79"

query = urllib.parse.quote(input("검색 질의: ")) #입력한 문자열을 utf-8로 바꾸어 변수에 할당
idx = 0
display = 100
start = 1
end = 1000
sort = "sim" #sim: 유사도순, date: 날짜순, asc: 가격오름차순, dsc: 가격내림차순

shop_df = pd.DataFrame(columns=("Title", "Link", "Image", "Low Price", "High Price", "Mall Name", "Product ID", "Product Type", "Maker", "Brand"))

for start_index in range(start, end, display): #시작 위치 바뀌면서 100개 단위로, 총 1000개

  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):       #200: 정상적인 응답 받았다는 코드
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title']) #인자로 받은 문자열에서 정규식에 해당하는 부분 제거
        link = items[item_index]['link']
        image = items[item_index]['image']
        low_price = items[item_index]['lprice']
        high_price = items[item_index]['hprice']
        mall_name = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type, maker, brand] #데이터프레임에 할당
        idx += 1
  else:
      print("Error Code:" + rescode)

shop_df
# Out:
# 검색 질의: 컴퓨터
#                                             Title  ... Brand
# 0         프리미엄 게이밍 조립컴퓨터 배틀그라운드 오버워치 배그 본체 사무용 견적  ...  마루PC
# 1               아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...   아싸컴
# 2                           삼성전자 삼성 DM530ABE-L58A  ...    삼성
# 3                                 배틀그라운드 오버워치조립PC  ...
# 4                               LG전자 24V570-LRP1K  ...  LG전자
# ..                                            ...  ...   ...
# 995  컴퓨터 SSD240G/윈10/미니pc Tiny/i5 ThinkCentre M73  ...
# 996                            LG전자 22VD240-LX25K  ...  LG전자
# 997                    HP 400 G5 Mini i7-9700T FD  ...
# 998                         삼성전자 삼성 DM500T7Z-AD2S  ...    삼성
# 999         PC온스튜디오 조립컴퓨터 모니터세트 사무용 게임용 데스크탑 PC본체  ...
#
# [1000 rows x 10 columns]
