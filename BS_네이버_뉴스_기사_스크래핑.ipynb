# %% [markdown]
# # BeautifulSoup 네이버 뉴스 기사 스크래핑

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd


def get_news(query, page_num=10):

  news_df = pd.DataFrame(columns=("Title", "Link", "Press", "Datetime", "Article"))
  idx = 0

  url_query = quote(query) # utf8로 인코딩
  url = "https://search.naver.com/search.naver?where=news&sm=nws_hty&query=" + url_query
  
  for _ in range(0, page_num):

    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')
    links = soup.find_all('dd', {'class':'txt_inline'})

    for link in links:
      press = link.find('span', {'class':'_sp_each_source'}).get_text()
      news_url = link.find('a').get('href')
      

      if (news_url == '#'):  # news_url이 없는 경우
        continue
      else:
        news_link = urllib.request.urlopen(news_url).read()
        news_html = BeautifulSoup(news_link, 'html.parser')

        try:      #긁어오지 못하는 부분이 있더라도 continue하도록 예외처리
          title = news_html.find('h3', {'id':'articleTitle'}).get_text()
          datetime = news_html.find('span', {'class':'t11'}).get_text()
          article = news_html.find('div', {'id':'articleBodyContents'}).get_text()
          article = article.replace("// flash 오류를 우회하기 위한 함수 추가", "") #방지코드 제거
          article = article.replace("function _flash_removeCallback() {}", "") #방지코드 제거
          article = article.replace("\n", "") #개인문자 제거
          article = article.replace("\t", "")
        
          news_df.loc[idx] = [title, news_url, press, datetime, article]
          idx += 1
          print("#", end="")
        except:
          continue

    try:
      next = soup.find('a', {'class':'next'}).get('href')
      url = "https://search.naver.com/search.naver" + next
    except:
      break

  return news_df

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행

# %%
query = input('검색 질의: ')
news_df = get_news(query, 10)
print('Done')
# Out:
# 검색 질의: 인공지능
# #################################Done

# %%
news_df
# Out:
#                                                 Title  ...                                            Article
# 0                          한국인공지능학회, 여수 학술대회 온라인으로 전환  ...  [한국인공지능학회 홈페이지 캡처. 재판매 및 DB 금지]     (대전=연합뉴스) ...
# 1                 경기창조경제혁신센터 '인공지능 투자유치 지원 IR DAY' 개최  ...  2020 K-Champ Forum; 인공지능 투자유치 지원 IR DAY. 제공|경기...
# 2                   ‘인공지능 보스’에 열광하는 유저들…게임업계 판도 바꾼 AI  ...  -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 3                인공지능 기반 자율방역 로봇 등 40개 개발과제에 370억원 지원  ...  과기부 '비대면 비즈니스 디지털혁신 기술개발' 과제 40개 선정(서울=연합뉴스) 정...
# 4                   ‘인공지능 보스’에 열광하는 유저들…게임업계 판도 바꾼 AI  ...  -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 5                        제이엘케이, 터키서 인공지능 의료기기 7건 품목허가  ...  제이엘케이는 인공지능 기반 폐 컴퓨터단층촬영(CT) 영상 진단보조소프트웨어 등 7개...
# 6     [2021학년도 대학 수시모집] 서울과기대, 인공지능응용학과 신입생 4년 전액 장학금  ...  [서울경제] 서울과학기술대는 2021학년도 수시모집으로 1,525명을 선발한다. 전...
# 7               [김정호의 AI시대의 전략] 양자역학과 인공지능의 공통점은 불확실성  ...  나노미터(10억분의 1m) 크기 원자나 분자 영역에서 일어나는 미시 세계 물리적인 ...
# 8                           언택트 시대 맞춰 인공지능 콜센터 빠르게 확대  ...  AI 실시간 상담도우미 시스템 및 고객상담 챗봇 화면 예시 (NH농협은행) 인공지능...
# 9                       가천대학교, 국내 1호 인공지능학부…150명으로 확대  ...  2021학년도 대입 수시가천대 캠퍼스 전경가천대(입학처장 이재희·사진)는 2021학...
# 10                 서울과학기술대학교, '인공지능응용학과' 최대 9년 전액 장학금  ...  2021학년도 대입 수시서울과학기술대 다산관 전경서울과학기술대(입학관리본부장 신현상...
# 11  [윤희영의 News English] F16 탑건과 인공지능 조종사의 공중전 대결 :...  ...  이세돌 9단과 '알파고'의 바둑 대결은 1대4로 인공지능(AI·Artificial ...
# 12                  현직 교사 5000명 '인공지능 융합교육 전문교사'로 키운다  ...  "수업에서 인공지능을 활용하는 역량이 갈수록 중요해질 것"유은혜 부총리 겸 교육부 ...
# 13        [2021학년도 대학 수시모집] 중앙대, 인공지능학과 등 일부 합격생에 장학금  ...  [서울경제] 중앙대는 2021학년도 수시모집에서 전체 모집인원 4,919명 중 69...
# 14  [교육이 미래다] IT융합소프트웨어학과 신설 … 인공지능을 뛰어 넘는 ‘H+ 인재’...  ...  서울신학대학교내년 개교 110주년 맞아 학과 개편첨단산업 이끌 스마트한 인재 양성H...
# 15                           '한국 오는 해외확진자' 인공지능이 예측한다  ...  24일 공군 공중급유기 'KC-330'를 타고 인천공항에 도착한 이라크 파견 근로자...
# 16                   중기부, 아마존·MS 등 손 잡고 인공지능 스타트업 키운다  ...  일러스트=김성규중소벤처기업부가 아마존·마이크로소프트 등과 손잡고 인공지능(AI) 스...
# 17                        미세조직 데이터만으로 재료강도 예측 인공지능 개발  ...  경상대 성효경, 한동대 정임두, 포스텍 박성진 교수 연구팀[윤성효 기자]      ...
# 18                               대구시, 인공지능·블록체인 인재 양성  ...  [KBS 대구]대구시가 인공지능과 블록체인 등 미래 유망분야의 실무형 소프트웨어 인...
# 19          (주)서포트유, 인공지능 학습용 데이터 구축사업을 위한 컨소시엄 협약 체결  ...   지난 8월 12일 충남 천안소재 충남경제진흥원 산하 창업마루나비 컨퍼런스 룸에서 ...
# 20                    '도로 위 지뢰' 포트홀, 인공지능 탐지 기술 현장 적용  ...  국토부, '도로파임관리 디지털화' 추진[서울=뉴시스] [서울=뉴시스] 이인준 기자 ...
# 21                       광주에 산·학·연 참여 인공지능(AI) 합작사 설립  ...  광주형 AI 비즈니스 29~30번째 업무협약 광주시-대신정보통신·스누아이랩-GIST...
# 22                        [IT 칼럼]‘머니게임’으로 치닫는 인공지능 개발  ...  [주간경향] GPT-3가 핫하다. 인기로만 따지면 인공지능 업계의 ‘아이돌’급이다....
# 23                    광주정보문화산업진흥원...인공지능중심도시 실현 중추 역할  ...  지역 문화콘텐츠·정보통신산업 육성 경제활성화 주도원장 직속의 인공지능·콘텐츠 기업지...
# 24                          코로나19 해외유입 확진자수 인공지능으로 예측  ...  코로나19 해외유입 확진자 수 예측 방법의 모식도. KAIST 제공.  수도권을 중...
# 25               트라이본즈, 업계최초 인공지능 맞춤셔츠 플랫폼 ‘셔츠스펙터’ 공개  ...  [스포츠경향] 인공지능, AI기술을 활용해 온라인 터치 몇번만으로 나에게 딱맞는 맞...
# 26              KB국민은행, 인공지능 경진대회 '퓨처 파이낸스 AI 챌린지' 개최  ...  KB국민은행은 인공지능 경진대회인 제2회 '퓨처 파이낸스 AI 챌린지(Future ...
# 27                             광주광역시, 인공지능 전문인력 양성 박차  ...  과기부 '지역ICT이노베이션스퀘어 조성사업' 선정...국비 200억원 확보  【파이...
# 28                     코로나19 해외 유입 확진자 수, 인공지능으로 예측한다  ...   [앵커] 수도권 교회발 코로나19의 전국적인 재확산이 크게 우려되는 가운데,  해...
# 29                       부울경 손잡고 인공지능·블록체인 전문가 3천명 양성  ...  'ICT 이노베이션 스퀘어' 공모에 부울경 컨소시엄 선정국비 200억 투입·소프트웨...
# 30                       LGU+, 5G 서비스품질 향상작업에 인공지능 투입  ...  18일 '5G AI+'시스템 가동...통화품질 향상고객별 상황에 맞게 기지국 등 자...
# 31            인공지능 활용 약물 재창출 방법으로 '코로나19' 치료제 중심특허 발굴  ...  중심특허 11건 한국생명정보학회서 발표특허청 "연구자들 활용하면 치료제 개발 도움될...
# 32                         인공지능 붙으니...MRI 검사속도 4배 빨라져  ...  fastMRI 프로젝트 이미지 캡처인공지능(AI)을 활용해 현재보다 4배 빠르게 자...
#
# [33 rows x 5 columns]

# %%
news_df['Article']
# Out:
# 0     [한국인공지능학회 홈페이지 캡처. 재판매 및 DB 금지]     (대전=연합뉴스) ...
# 1     2020 K-Champ Forum; 인공지능 투자유치 지원 IR DAY. 제공|경기...
# 2     -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 3     과기부 '비대면 비즈니스 디지털혁신 기술개발' 과제 40개 선정(서울=연합뉴스) 정...
# 4     -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 5     제이엘케이는 인공지능 기반 폐 컴퓨터단층촬영(CT) 영상 진단보조소프트웨어 등 7개...
# 6     [서울경제] 서울과학기술대는 2021학년도 수시모집으로 1,525명을 선발한다. 전...
# 7     나노미터(10억분의 1m) 크기 원자나 분자 영역에서 일어나는 미시 세계 물리적인 ...
# 8     AI 실시간 상담도우미 시스템 및 고객상담 챗봇 화면 예시 (NH농협은행) 인공지능...
# 9     2021학년도 대입 수시가천대 캠퍼스 전경가천대(입학처장 이재희·사진)는 2021학...
# 10    2021학년도 대입 수시서울과학기술대 다산관 전경서울과학기술대(입학관리본부장 신현상...
# 11    이세돌 9단과 '알파고'의 바둑 대결은 1대4로 인공지능(AI·Artificial ...
# 12    "수업에서 인공지능을 활용하는 역량이 갈수록 중요해질 것"유은혜 부총리 겸 교육부 ...
# 13    [서울경제] 중앙대는 2021학년도 수시모집에서 전체 모집인원 4,919명 중 69...
# 14    서울신학대학교내년 개교 110주년 맞아 학과 개편첨단산업 이끌 스마트한 인재 양성H...
# 15    24일 공군 공중급유기 'KC-330'를 타고 인천공항에 도착한 이라크 파견 근로자...
# 16    일러스트=김성규중소벤처기업부가 아마존·마이크로소프트 등과 손잡고 인공지능(AI) 스...
# 17    경상대 성효경, 한동대 정임두, 포스텍 박성진 교수 연구팀[윤성효 기자]      ...
# 18    [KBS 대구]대구시가 인공지능과 블록체인 등 미래 유망분야의 실무형 소프트웨어 인...
# 19     지난 8월 12일 충남 천안소재 충남경제진흥원 산하 창업마루나비 컨퍼런스 룸에서 ...
# 20    국토부, '도로파임관리 디지털화' 추진[서울=뉴시스] [서울=뉴시스] 이인준 기자 ...
# 21    광주형 AI 비즈니스 29~30번째 업무협약 광주시-대신정보통신·스누아이랩-GIST...
# 22    [주간경향] GPT-3가 핫하다. 인기로만 따지면 인공지능 업계의 ‘아이돌’급이다....
# 23    지역 문화콘텐츠·정보통신산업 육성 경제활성화 주도원장 직속의 인공지능·콘텐츠 기업지...
# 24    코로나19 해외유입 확진자 수 예측 방법의 모식도. KAIST 제공.  수도권을 중...
# 25    [스포츠경향] 인공지능, AI기술을 활용해 온라인 터치 몇번만으로 나에게 딱맞는 맞...
# 26    KB국민은행은 인공지능 경진대회인 제2회 '퓨처 파이낸스 AI 챌린지(Future ...
# 27    과기부 '지역ICT이노베이션스퀘어 조성사업' 선정...국비 200억원 확보  【파이...
# 28     [앵커] 수도권 교회발 코로나19의 전국적인 재확산이 크게 우려되는 가운데,  해...
# 29    'ICT 이노베이션 스퀘어' 공모에 부울경 컨소시엄 선정국비 200억 투입·소프트웨...
# 30    18일 '5G AI+'시스템 가동...통화품질 향상고객별 상황에 맞게 기지국 등 자...
# 31    중심특허 11건 한국생명정보학회서 발표특허청 "연구자들 활용하면 치료제 개발 도움될...
# 32    fastMRI 프로젝트 이미지 캡처인공지능(AI)을 활용해 현재보다 4배 빠르게 자...
# Name: Article, dtype: object
